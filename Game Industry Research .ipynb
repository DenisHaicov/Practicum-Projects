# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hello, my name is Sveta Nosova and I am going to review this project.
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content, however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> please, make sure that the correct path is used so I can review the code.
#
#
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for correcting the path. You've done a great job, I really appreciate it. I've left a few comments titled as **Reviewer's comment 2**. I still have some questions that I've written in my comments. Please, check them out.
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
#
# Hi again! My new comments are titled as **Reviewer's comment 3**. Some issues were not fixed and some cells still do not work. Please, make sure that the whole project can be run so I can finish the review.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4</b>
#
#
# You did a fantastic job in this project. My new comments are titled as **Reviewer's comment 4**. There are several questions left. It should not take much time.
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 5</b>
#
#
# We almost there :) New comments are titled as **Reviewer's comment 5**. I've also removed the headings from the old comments.
#
#
# It seems that you may be confused with the *relevant data*. The point is, in order to conduct a persuasive analysis and to determine trends, we have to use fresh data, fresh time period. You have already done it in the cell `relevant_data = data[data['year_of_release'] >= 2012]`. After  this use only `relevant_data` dataframe. It shoould give us a proper estimation of scores, popular platforms and genres.
# </div>
# <hr>
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 6</b>
#
#
# Thank you very much, the project is getting better and better! We are close to make it perfect! Please, check out my new comments, the corrections should not take much time :)
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 7</b>
#
#
# Me new comments are titled as **Reviewer's comment 7**.
#
# Your project has passed code review. Congratulations 😊
#
#
# <hr>
# Here are some recommendations:
#
# - Try not to forget reconsidering the conclusion after the code has been changed.
#
#
# - It's a good practice to leave a comment under each result, whatever it is: a graph, a table or just some number.
#
#
# - Do not forget to add titles and labels on your graphs.
#
#
# <hr>
#
# Good luck! 😊
#
#
# <hr>
#
#
# Best regards,
#
# S. N.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# First things first. The introduction is the initial paragraph that each project, each essay or any article should have. It is important to write an introductory part, because it gives an idea about the content of the project. Please, add project and descriptions.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
# Please, add some intro. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 </b>
#
# And there's still no intro.  </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# Great! :) It's a good habit actually. I have about 200 notebooks on my laptop with different tasks. Without a good intro it would be hard to remember what a particular notebook is about.
#
# </div>

# %% [markdown]
# # Introduction
# In this project, us, a small company of video games, want to check and find out what consoles are still relevant and which consoles and long gone, so we would know which games we should acquire for the next year of 2017.
# I am going to check the data of the platform and their patter and how they acted years before and to undestand how to prepare for 2017.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment</b>
#
# Local path is used :)
#
#
# Just run all the cells before sending the project:
#
#
# ![image.png](attachment:image.png)</div>

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# From the get-go, I can notice that we are dealing with 2 columns(Name and Year_of_release) that have some minor missing values and the last 3 columns(Critic score, User score and Rating) that are barely half of all the lines.
# There is a problem with the type of the year or release(needs to be changed to int) and also for critic score should be changed to int.
# Also, We should lower the the column names.

# %%
data.columns = data.columns.str.lower()

# %%
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 0         41.36     28.96      3.77         8.45          76.0          8
# 1         29.08      3.58      6.81         0.77           NaN        NaN
# 2         15.68     12.76      3.79         3.29          82.0        8.3
# 3         15.61     10.93      3.28         2.95          80.0          8
# 4         11.27      8.89     10.22         1.00           NaN        NaN
# ...         ...       ...       ...          ...           ...        ...
# 16710      0.00      0.00      0.01         0.00           NaN        NaN
# 16711      0.00      0.01      0.00         0.00           NaN        NaN
# 16712      0.00      0.00      0.01         0.00           NaN        NaN
# 16713      0.01      0.00      0.00         0.00           NaN        NaN
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
#
#       rating
# 0          E
# 1        NaN
# 2          E
# 3          E
# 4        NaN
# ...      ...
# 16710    NaN
# 16711    NaN
# 16712    NaN
# 16713    NaN
# 16714    NaN
#
# [16715 rows x 11 columns]

# %% [markdown]
# Now, after i changed the lowercases, i should adress the missing values so it will be easier to perform reaserches on them and change data types.

# %%
def missing_values(data):
    
    report = data.isna().sum().to_frame()
    report = report.rename(columns = {0: 'missing_values'})
    report['% of total'] = ((report['missing_values'] / data.shape[0]) *100).round(2)
    display(report)

missing_values(data)
# Out:
#                  missing_values  % of total
# name                          2        0.01
# platform                      0        0.00
# year_of_release             269        1.61
# genre                         2        0.01
# na_sales                      0        0.00
# eu_sales                      0        0.00
# jp_sales                      0        0.00
# other_sales                   0        0.00
# critic_score               8578       51.32
# user_score                 6701       40.09
# rating                     6766       40.48

# %%
data['year_of_release'].value_counts()
# Out:
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2007.0    1197
# 2011.0    1136
# 2006.0    1006
# 2005.0     939
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2012.0     653
# 2015.0     606
# 2014.0     581
# 2013.0     544
# 2016.0     502
# 2001.0     482
# 1998.0     379
# 2000.0     350
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      62
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1987.0      16
# 1990.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      14
# 1980.0       9
# Name: year_of_release, dtype: int64

# %%
data['name'] = data['name'].fillna('Unknown')

# %%
data['genre'] = data['genre'].fillna('Unknown')

# %%
data['year_of_release'] = data['year_of_release'].fillna(data.groupby(['platform'])['year_of_release'].transform('median'))

# %% [markdown]
# I decided to group the missing data of the year of the release by the platform because it was the most close thing to get to the truth of the missing values about the year.
# About the name and genre, it was only 2 missing values so i decided just to fillna them as unknown.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Yes, the year of release can be taken from other platforms (e.g. group data by platform and take the median year of release) assuming that platform's lifespan is limited. Usually there's a small difference between these years. Moreover, some games have a year in their names. These are sports games and the year in the title is the end year of the season. But you can also delete or ignore them, that's ok.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# But it's better to use a median.
# </div>

# %%
data['year_of_release'] = data['year_of_release'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16715.000000  16715.000000  16715.000000  16715.000000
# mean       2006.473347      0.263377      0.145060      0.077617
# std           5.897579      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
data.describe(include=['object'])
# Out:
#                                name platform   genre user_score rating
# count                         16715    16715   16715      10014   9949
# unique                        11560       31      13         96      8
# top     Need for Speed: Most Wanted      PS2  Action        tbd      E
# freq                             12     2161    3369       2424   3990

# %% [markdown]
# I can notice that most of the missing values in user_score are "tbd"(to be determined).
# I will try to isolate the prolem and check it and after to fix it.

# %%
data[data.user_score == 'tbd']
# Out:
#                                            name platform  year_of_release  \
# 119                               Zumba Fitness      Wii             2010
# 301              Namco Museum: 50th Anniversary      PS2             2005
# 520                             Zumba Fitness 2      Wii             2011
# 645                                uDraw Studio      Wii             2010
# 657    Frogger's Adventures: Temple of the Frog      GBA             2003
# ...                                         ...      ...              ...
# 16695                           Planet Monsters      GBA             2001
# 16697                          Bust-A-Move 3000       GC             2003
# 16698                          Mega Brain Boost       DS             2008
# 16704                                  Plushees       DS             2008
# 16706             Men in Black II: Alien Escape       GC             2003
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 119        Sports      3.45      2.59       0.0         0.66           NaN
# 301          Misc      2.08      1.35       0.0         0.54          61.0
# 520        Sports      1.51      1.03       0.0         0.27           NaN
# 645          Misc      1.65      0.57       0.0         0.20          71.0
# 657     Adventure      2.15      0.18       0.0         0.07          73.0
# ...           ...       ...       ...       ...          ...           ...
# 16695      Action      0.01      0.00       0.0         0.00          67.0
# 16697      Puzzle      0.01      0.00       0.0         0.00          53.0
# 16698      Puzzle      0.01      0.00       0.0         0.00          48.0
# 16704  Simulation      0.01      0.00       0.0         0.00           NaN
# 16706     Shooter      0.01      0.00       0.0         0.00           NaN
#
#       user_score rating
# 119          tbd      E
# 301          tbd   E10+
# 520          tbd      T
# 645          tbd      E
# 657          tbd      E
# ...          ...    ...
# 16695        tbd      E
# 16697        tbd      E
# 16698        tbd      E
# 16704        tbd      E
# 16706        tbd      T
#
# [2424 rows x 11 columns]

# %%
data[data.user_score == 'tbd']['year_of_release'].value_counts()
# Out:
# 2009    422
# 2008    338
# 2010    332
# 2011    217
# 2002    192
# 2007    192
# 2005    125
# 2006    124
# 2004    111
# 2003    102
# 2001     82
# 2000     43
# 2015     38
# 2016     34
# 2012     24
# 2014     21
# 2013     17
# 1999      8
# 1998      1
# 1997      1
# Name: year_of_release, dtype: int64

# %%
data['user_score'].isna().sum()
# Out:
# 6701

# %%
data['user_score'] = data['user_score'].replace(['tbd'], np.nan)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Yes, we can treat it as a missing value.
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
data['user_score'] = data['user_score'].astype('float')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Hm.. I am not sure, to be honest. I think that different games can have disparate ratings on several platforms. One can really have a different perception playing some game on different platforms, since platforms have their own characteristics. It's hard to figure out a decent replacement for these Nan-s.
#
# What is more important here is that we are trying to replace 50% values, which mean that the half of the column is going to be artificial. It may play an important role in hypotheses testing.
#
#
# What do you think about it? Should we just ignore the missing values in critics' and users' ratings?
#
# </div>

# %% [markdown]
# Well, I think that correcting 10% of all the 50% that is missing relying on the same game in different platform on one hand doesnt affects all the 50% that much but on the other hand it gives a pretty accurate rating(since gaming mostly relies on the enjoyment and less on which platform it is played on).
# As for the rating, I think that you are right and I should just ignore it and leave the 50% as Nan because I cant even get close to the truth on rating.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
#
# I mean it's not a good approach to replace 50% of data. Hence, we should not even try it. Even if we replace only 10-20% eventually, we should not try this approach. 10% is a large number of rows. Do you agree with it?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# I see the changes. Yes, it's just much safer. Please, do not be afaid of ignoring missing values :)
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %%
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# There's the same issue here.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# So here it's safer to ignore these values as well.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# This one still needs to be fixed. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5 </b>
#
# Now it's good :)
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# And here :)
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
#
# 👌
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16715 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# To change the missing values I had alot of columns to adress.
# 1. I needed to fix the data in the year of release that was missing  around 250 rows. I decided to group it with the Platform column because in those times, each release of a game was pretty close to the platform that was given, and we didnt had any better way to know which data can help us.
# 2. We also had 2 rows missing in name and genre, and because it wasnt that of a big deal, i decided to mark them as Unknown.
# 3. Then I needed to adress the missing values in critic score, user score and rating and we had alot of missing values in them(around 50%!).
# We couldn't know what is the rating that can be for each game so i decided to use the score of the same game on diffreent platform and to atach it the same score with the mean/median to get at least close to the truth but I managed to fix only 10-20% of the whole missing values for them.
# As for the rating, I coudnt groupby the mead or median because it contained object values and not int/float numbers so i used moad and groupedby with the name again.

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %%
data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %%
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0         41.36     28.96      3.77         8.45          76.0         8.0
# 1         29.08      3.58      6.81         0.77           NaN         NaN
# 2         15.68     12.76      3.79         3.29          82.0         8.3
# 3         15.61     10.93      3.28         2.95          80.0         8.0
# 4         11.27      8.89     10.22         1.00           NaN         NaN
# ...         ...       ...       ...          ...           ...         ...
# 16710      0.00      0.00      0.01         0.00           NaN         NaN
# 16711      0.00      0.01      0.00         0.00           NaN         NaN
# 16712      0.00      0.00      0.01         0.00           NaN         NaN
# 16713      0.01      0.00      0.00         0.00           NaN         NaN
# 16714      0.00      0.00      0.01         0.00           NaN         NaN
#
#       rating  total_sales
# 0          E        82.54
# 1        NaN        40.24
# 2          E        35.52
# 3          E        32.77
# 4        NaN        31.38
# ...      ...          ...
# 16710    NaN         0.01
# 16711    NaN         0.01
# 16712    NaN         0.01
# 16713    NaN         0.01
# 16714    NaN         0.01
#
# [16715 rows x 12 columns]

# %% [markdown]
# I summed all the sales of the 4 columns for each row and now I can start with analysing the data.
# # Analysing Data

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Good job here :)
# </div>

# %% [markdown]
# ### Look at how many games were released in different years. Is the data for every period significant?

# %%
new_data = data[['year_of_release', 'name']].groupby(['year_of_release']).count().sort_values(by='year_of_release').reset_index()

# %%
new_data
# Out:
#     year_of_release  name
# 0              1980     9
# 1              1981    46
# 2              1982    53
# 3              1983    17
# 4              1984    14
# 5              1985    14
# 6              1986    21
# 7              1987    16
# 8              1988    15
# 9              1989    17
# 10             1990    16
# 11             1991    41
# 12             1992    43
# 13             1993    62
# 14             1994   121
# 15             1995   219
# 16             1996   263
# 17             1997   290
# 18             1998   386
# 19             1999   341
# 20             2000   350
# 21             2001   482
# 22             2002   829
# 23             2003   800
# 24             2004   783
# 25             2005   973
# 26             2006  1006
# 27             2007  1197
# 28             2008  1457
# 29             2009  1476
# 30             2010  1302
# 31             2011  1161
# 32             2012   653
# 33             2013   552
# 34             2014   582
# 35             2015   606
# 36             2016   502

# %% [markdown]
# We can notice that the peak of our game industry releases, from 2006 till 2011 was the highest that was between 1000-1550.
# I think it peaked at the 2008 with the most releases and then started falling maybe because of the crysis in 2008 that the economy collapsed and maybe it hurt alot of the small game companies.

# %%
fig, ax=plt.subplots(figsize=(15,10))
ax.vlines(x=new_data['year_of_release'], ymin=0, ymax=new_data['name'], color='blue', alpha=0.7, linewidth=3)
ax.scatter(x=new_data['year_of_release'], y=new_data['name'], s=80, color='black', alpha=0.9)

ax.set_title('Released Games by Year', fontdict={'size':20})
ax.set_ylabel('Number of Games', fontdict={'size':15})
ax.set_xticks(new_data['year_of_release'])
ax.set_xticklabels(new_data['year_of_release'], rotation=90)
ax.axhline(y=500)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# I like this graph! 😊  Don't forget that xticklabels can be rotated `plt.xticks(rotation= )`. Just define the angle you want. </div>

# %% [markdown]
# As we can see, the gaming industry started growing sagnificantly from 2002 to 2010 that the game releases jumped from 500 to over 800 games per year and peaked at years 2008-2009 and then started falling drastically.
# I mentioned before that I think reason of the fall down was because of the crysis in the markets that collapsed the economy and it effected everyone, including the gaming industry.

# %% [markdown]
# ### Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?

# %%
new_data = data[['platform', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()

# %%
new_data
# Out:
#    platform  na_sales  eu_sales  jp_sales  other_sales  total_sales
# 0      PCFX      0.00      0.00      0.03         0.00         0.03
# 1        GG      0.00      0.00      0.04         0.00         0.04
# 2       3DO      0.00      0.00      0.10         0.00         0.10
# 3      TG16      0.00      0.00      0.16         0.00         0.16
# 4        WS      0.00      0.00      1.42         0.00         1.42
# 5        NG      0.00      0.00      1.44         0.00         1.44
# 6       SCD      1.00      0.36      0.45         0.05         1.86
# 7        DC      5.43      1.69      8.56         0.27        15.95
# 8       GEN     21.05      6.05      2.70         0.97        30.77
# 9       SAT      0.72      0.54     32.26         0.07        33.59
# 10      PSV     12.58     13.12     21.91         6.46        54.07
# 11     WiiU     38.10     25.13     13.01         5.95        82.19
# 12     2600     90.60      5.47      0.00         0.91        96.98
# 13     XOne     93.12     51.59      0.34        14.27       159.32
# 14       GC    133.46     38.71     21.58         5.18       198.93
# 15     SNES     61.23     19.04    116.55         3.22       200.04
# 16      N64    139.02     41.06     34.22         4.38       218.68
# 17      NES    125.94     21.15     98.65         5.31       251.05
# 18       GB    114.32     47.82     85.12         8.20       255.46
# 19       XB    186.69     60.95      1.38         8.72       257.74
# 20      3DS     83.49     61.48    100.67        13.36       259.00
# 21       PC     94.53    142.44      0.17        22.38       259.52
# 22      PSP    109.17     66.68     76.78        41.42       294.05
# 23      PS4    108.74    141.09     15.96        48.35       314.14
# 24      GBA    187.54     75.25     47.33         7.73       317.85
# 25       PS    336.52    213.61    139.82        40.91       730.86
# 26       DS    382.40    188.89    175.57        59.26       806.12
# 27      Wii    496.90    262.21     69.33        79.07       907.51
# 28      PS3    393.49    330.29     80.19       135.68       939.65
# 29     X360    602.47    270.76     12.43        85.76       971.42
# 30      PS2    583.84    339.29    139.20       193.44      1255.77

# %%
new_data['sales_std'] = (new_data['total_sales']-new_data['total_sales'].mean())/new_data['total_sales'].std()

# %%
new_data
# Out:
#    platform  na_sales  eu_sales  jp_sales  other_sales  total_sales  sales_std
# 0      PCFX      0.00      0.00      0.03         0.00         0.03  -0.825980
# 1        GG      0.00      0.00      0.04         0.00         0.04  -0.825952
# 2       3DO      0.00      0.00      0.10         0.00         0.10  -0.825779
# 3      TG16      0.00      0.00      0.16         0.00         0.16  -0.825607
# 4        WS      0.00      0.00      1.42         0.00         1.42  -0.821988
# 5        NG      0.00      0.00      1.44         0.00         1.44  -0.821931
# 6       SCD      1.00      0.36      0.45         0.05         1.86  -0.820724
# 7        DC      5.43      1.69      8.56         0.27        15.95  -0.780254
# 8       GEN     21.05      6.05      2.70         0.97        30.77  -0.737688
# 9       SAT      0.72      0.54     32.26         0.07        33.59  -0.729588
# 10      PSV     12.58     13.12     21.91         6.46        54.07  -0.670765
# 11     WiiU     38.10     25.13     13.01         5.95        82.19  -0.589997
# 12     2600     90.60      5.47      0.00         0.91        96.98  -0.547517
# 13     XOne     93.12     51.59      0.34        14.27       159.32  -0.368461
# 14       GC    133.46     38.71     21.58         5.18       198.93  -0.254692
# 15     SNES     61.23     19.04    116.55         3.22       200.04  -0.251504
# 16      N64    139.02     41.06     34.22         4.38       218.68  -0.197965
# 17      NES    125.94     21.15     98.65         5.31       251.05  -0.104991
# 18       GB    114.32     47.82     85.12         8.20       255.46  -0.092324
# 19       XB    186.69     60.95      1.38         8.72       257.74  -0.085775
# 20      3DS     83.49     61.48    100.67        13.36       259.00  -0.082156
# 21       PC     94.53    142.44      0.17        22.38       259.52  -0.080663
# 22      PSP    109.17     66.68     76.78        41.42       294.05   0.018516
# 23      PS4    108.74    141.09     15.96        48.35       314.14   0.076219
# 24      GBA    187.54     75.25     47.33         7.73       317.85   0.086875
# 25       PS    336.52    213.61    139.82        40.91       730.86   1.273139
# 26       DS    382.40    188.89    175.57        59.26       806.12   1.489304
# 27      Wii    496.90    262.21     69.33        79.07       907.51   1.780520
# 28      PS3    393.49    330.29     80.19       135.68       939.65   1.872834
# 29     X360    602.47    270.76     12.43        85.76       971.42   1.964085
# 30      PS2    583.84    339.29    139.20       193.44      1255.77   2.780807

# %%
new_data['color']=['red' if x<0 else 'green' for x in new_data['sales_std']]

# %%
new_data
# Out:
#    platform  na_sales  eu_sales  jp_sales  other_sales  total_sales  \
# 0      PCFX      0.00      0.00      0.03         0.00         0.03
# 1        GG      0.00      0.00      0.04         0.00         0.04
# 2       3DO      0.00      0.00      0.10         0.00         0.10
# 3      TG16      0.00      0.00      0.16         0.00         0.16
# 4        WS      0.00      0.00      1.42         0.00         1.42
# 5        NG      0.00      0.00      1.44         0.00         1.44
# 6       SCD      1.00      0.36      0.45         0.05         1.86
# 7        DC      5.43      1.69      8.56         0.27        15.95
# 8       GEN     21.05      6.05      2.70         0.97        30.77
# 9       SAT      0.72      0.54     32.26         0.07        33.59
# 10      PSV     12.58     13.12     21.91         6.46        54.07
# 11     WiiU     38.10     25.13     13.01         5.95        82.19
# 12     2600     90.60      5.47      0.00         0.91        96.98
# 13     XOne     93.12     51.59      0.34        14.27       159.32
# 14       GC    133.46     38.71     21.58         5.18       198.93
# 15     SNES     61.23     19.04    116.55         3.22       200.04
# 16      N64    139.02     41.06     34.22         4.38       218.68
# 17      NES    125.94     21.15     98.65         5.31       251.05
# 18       GB    114.32     47.82     85.12         8.20       255.46
# 19       XB    186.69     60.95      1.38         8.72       257.74
# 20      3DS     83.49     61.48    100.67        13.36       259.00
# 21       PC     94.53    142.44      0.17        22.38       259.52
# 22      PSP    109.17     66.68     76.78        41.42       294.05
# 23      PS4    108.74    141.09     15.96        48.35       314.14
# 24      GBA    187.54     75.25     47.33         7.73       317.85
# 25       PS    336.52    213.61    139.82        40.91       730.86
# 26       DS    382.40    188.89    175.57        59.26       806.12
# 27      Wii    496.90    262.21     69.33        79.07       907.51
# 28      PS3    393.49    330.29     80.19       135.68       939.65
# 29     X360    602.47    270.76     12.43        85.76       971.42
# 30      PS2    583.84    339.29    139.20       193.44      1255.77
#
#     sales_std  color
# 0   -0.825980    red
# 1   -0.825952    red
# 2   -0.825779    red
# 3   -0.825607    red
# 4   -0.821988    red
# 5   -0.821931    red
# 6   -0.820724    red
# 7   -0.780254    red
# 8   -0.737688    red
# 9   -0.729588    red
# 10  -0.670765    red
# 11  -0.589997    red
# 12  -0.547517    red
# 13  -0.368461    red
# 14  -0.254692    red
# 15  -0.251504    red
# 16  -0.197965    red
# 17  -0.104991    red
# 18  -0.092324    red
# 19  -0.085775    red
# 20  -0.082156    red
# 21  -0.080663    red
# 22   0.018516  green
# 23   0.076219  green
# 24   0.086875  green
# 25   1.273139  green
# 26   1.489304  green
# 27   1.780520  green
# 28   1.872834  green
# 29   1.964085  green
# 30   2.780807  green

# %%
plt.figure(figsize=(15,10))
plt.hlines(y=new_data['platform'], xmax = new_data['sales_std'], xmin=0, color=new_data['color'], alpha=0.7, linewidth=15)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Good idea!  </div>

# %% [markdown]
# After creating a new data, I used this data here to groupby all of the column sales by the platfor to see which platfor had the most sales.But, it was enough because we needed to check how the sales are acting towards the mean of the sales deviding by the standart deviation.
# As we have seen, most of the platform are under performing(marked as "red") and only 9 platform are over performing(marked as "green) when PS2 is at the top. Also, we can notice in the diagram that we printed, that the outliers in the green part are very high and are pulling all of the data that way because they are extremley over performing.(talking about PS2 expecially)

# %%
new_data = data[data['year_of_release'] >= 2000]

# %%
plat_age = new_data.groupby(['platform'])['year_of_release'].agg(['min', 'max'])

# %%
plat_age['age'] = plat_age['max']-plat_age['min']

# %%
plat_age['age'].median()
# Out:
# 6.5

# %%
plat_age = plat_age.reset_index()

# %%
plat_age.sort_values(by='age')
# Out:
#    platform   min   max  age
# 14       WS  2000  2001    1
# 3        GB  2000  2001    1
# 6       N64  2000  2002    2
# 19     XOne  2013  2016    3
# 11      PS4  2013  2016    3
# 8        PS  2000  2003    3
# 16     WiiU  2012  2016    4
# 13      PSV  2011  2016    5
# 0       3DS  2011  2016    5
# 5        GC  2001  2007    6
# 4       GBA  2000  2007    7
# 18       XB  2000  2008    8
# 1        DC  2000  2008    8
# 2        DS  2004  2013    9
# 10      PS3  2006  2016   10
# 15      Wii  2006  2016   10
# 12      PSP  2004  2015   11
# 17     X360  2005  2016   11
# 9       PS2  2000  2011   11
# 7        PC  2000  2016   16

# %%
new_data = new_data.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index().sort_values(by='year_of_release')

# %%
plt.figure(figsize=(15,10))
ax = sns.lineplot(data=new_data, x='year_of_release', y='total_sales', hue='platform')

# %% [markdown]
# In the early 2000, we can see that most of the platform(till the 2010) had more years in the industry but as the platforms became newer, the lasted less. I guess the reason was to acumulate more money from the customers by creating new platform each couple of years to generate more sales as the newwer edition came.
# The median for platform to last was around 6 and a half years( after we created an age column with the minimum and maximum).
# If the platform is older by the age, then it is closer to fading away.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Agree.
# </div>

# %% [markdown]
# ### Determine what period you should take data for. To do so, look at your answers to the previous questions. The data should allow you to build a prognosis for 2017.

# %% [markdown]
# After we noticed that most of the older games and their platform have faded away, we shouldn't use it because it wont affect our tests for the upcoming year. Since we can see that most of the gplatform already faded till the 2016, we should watch the platform that started rising only in the last few years. We can see that from the 2012-1013 we have new platform that have beed created and are still relrevant(PS4 or XOne for example)

# %% [markdown]
# ### Work only with the data that you've decided is relevant. Disregard the data for previous years.

# %%
relevant_data = data[data['year_of_release'] >= 2012]

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Totally agree.
# </div>

# %%
relevant_data
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34        Call of Duty: Black Ops II      PS3             2012       Shooter
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16         7.02      9.09      0.98         3.96          97.0         8.2
# 23         9.66      5.14      0.06         1.41          97.0         8.1
# 31         6.03      5.86      0.36         2.38           NaN         NaN
# 33         5.28      4.19      4.35         0.78           NaN         NaN
# 34         4.99      5.73      0.65         2.42          83.0         5.3
# ...         ...       ...       ...          ...           ...         ...
# 16703      0.00      0.00      0.01         0.00           NaN         NaN
# 16707      0.00      0.00      0.01         0.00           NaN         NaN
# 16710      0.00      0.00      0.01         0.00           NaN         NaN
# 16712      0.00      0.00      0.01         0.00           NaN         NaN
# 16714      0.00      0.00      0.01         0.00           NaN         NaN
#
#       rating  total_sales
# 16         M        21.05
# 23         M        16.27
# 31       NaN        14.63
# 33       NaN        14.60
# 34         M        13.79
# ...      ...          ...
# 16703    NaN         0.01
# 16707    NaN         0.01
# 16710    NaN         0.01
# 16712    NaN         0.01
# 16714    NaN         0.01
#
# [2895 rows x 12 columns]

# %% [markdown]
# ### Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.

# %%
relevant_data_new = relevant_data.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')

# %%
relevant_data_new
# Out:
# platform           3DS     DS     PC     PS3     PS4   PSP    PSV    Wii  \
# year_of_release
# 2012             51.36  11.01  23.22  107.36     NaN  7.69  16.19  21.71
# 2013             57.76   1.54  12.38  113.25   25.99  3.14  10.59   8.59
# 2014             43.76    NaN  13.28   47.76  100.00  0.24  12.16   3.75
# 2015             27.78    NaN   8.52   16.82  118.90  0.12   6.25   1.14
# 2016             15.14    NaN   5.25    3.60   69.25   NaN   4.25   0.18
#
# platform          WiiU   X360   XOne
# year_of_release
# 2012             17.56  99.74    NaN
# 2013             21.65  88.58  18.96
# 2014             22.03  34.74  54.07
# 2015             16.35  11.96  60.14
# 2016              4.60   1.52  26.15

# %%
relevant_data_new = relevant_data_new.drop(columns=['DS', 'PS3', 'PSP', 'Wii', 'X360'])

# %% [markdown]
# After aranging the table, we can notice that the PS4, XONE, PSV, WiiU, 3DS and PC are still relevant and still are generating growth and building up the cash flow, heading towards the 2017. We can discard the DS, PS3, PSP, Wii and x360 later on.

# %%
relevant_data_new - relevant_data_new.shift(+1)
# Out:
# platform           3DS     PC    PS4   PSV   WiiU   XOne
# year_of_release
# 2012               NaN    NaN    NaN   NaN    NaN    NaN
# 2013              6.40 -10.84    NaN -5.60   4.09    NaN
# 2014            -14.00   0.90  74.01  1.57   0.38  35.11
# 2015            -15.98  -4.76  18.90 -5.91  -5.68   6.07
# 2016            -12.64  -3.27 -49.65 -2.00 -11.75 -33.99

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Why did you decide to use shift?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# Got it. However, it's not the most reliable way. We know that 2016 year sales are not fully presented here. And it's completely normal. So I'd just print sales volumes, it should be enough.
# </div>

# %% [markdown]
# I decided to use the shift method to show how much does the platforms obtain growth in revenue and to see how they differ from last year to the next year.
# As you can see, the platforms do generate growth in revenue each year(even on the 2016) but each year its less and less then the previous one.

# %%
difference = relevant_data_new - relevant_data_new.shift(+1)
difference.T
# Out:
# year_of_release  2012   2013   2014   2015   2016
# platform
# 3DS               NaN   6.40 -14.00 -15.98 -12.64
# PC                NaN -10.84   0.90  -4.76  -3.27
# PS4               NaN    NaN  74.01  18.90 -49.65
# PSV               NaN  -5.60   1.57  -5.91  -2.00
# WiiU              NaN   4.09   0.38  -5.68 -11.75
# XOne              NaN    NaN  35.11   6.07 -33.99

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(difference.T, cmap='RdBu_r', annot=True)
# Out:
# <AxesSubplot:xlabel='year_of_release', ylabel='platform'>

# %% [markdown]
# I have created a pivot table and focused on the year of release, platform and the total sum to check how each platform since the 2012 is performing and already in the data we can see that towards the 2016 every platform is fading away.
# I decided to shift down the table so i can later decrease the main data from the shifted one to see what is the difference between each year on each platform.
# To visualize it better, I created a heatmap to see clearly what is going on, and we can notice that the main platform that are still relevant are the XOne(generated 26M in 2016) , 3DS(generated 15M in 2016), PC(generated 5M in 2016), PSV(generated 4M in 2016), WiiU(generated 4.6M in 2016) and ofcourse the most related platform for us is the PS4(generated almost 70M in 2016).

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6 </b>
#
# Great!
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
# > and we can notice that the main platform that are still relevant are the XOne, X360, WiiU, The PS3, 3DS and the PS4.
#
#
# Are X360, WiiU and PS3  still relevant? Please, adjust the conclusion here and the overall one. We can't say that they are relevant. Take a look at the sales dynamics. Their sale volumes have dropped significantly
#
# ![image.png](attachment:image.png)
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# By the way, are X360, WiiU and PS3  still relevant? Take a look, they have a huge decrease: </div>

# %%
# Reviewer's code

data.query('year_of_release>2011').pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS     DS     PC     PS3     PS4   PSP    PSV    Wii  \
# year_of_release
# 2012             51.36  11.01  23.22  107.36     NaN  7.69  16.19  21.71
# 2013             57.76   1.54  12.38  113.25   25.99  3.14  10.59   8.59
# 2014             43.76    NaN  13.28   47.76  100.00  0.24  12.16   3.75
# 2015             27.78    NaN   8.52   16.82  118.90  0.12   6.25   1.14
# 2016             15.14    NaN   5.25    3.60   69.25   NaN   4.25   0.18
#
# platform          WiiU   X360   XOne
# year_of_release
# 2012             17.56  99.74    NaN
# 2013             21.65  88.58  18.96
# 2014             22.03  34.74  54.07
# 2015             16.35  11.96  60.14
# 2016              4.60   1.52  26.15

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
#
# You're not obliged to use  methods that tutors show on their online lessons. Shift is a good method, but do we really need it when it is enough to compare the sales dynamics? </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# Are x360 and ps3 can be relevant? What do you think about these table?
#
# ![image.png](attachment:image.png)
#
#
#
# Do we actually need  to use shift?
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# Very good.
# </div>

# %% [markdown]
# ### Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.

# %%
global_sales = relevant_data.groupby(['platform', 'name'])['total_sales'].sum().reset_index()

# %%
global_sales
# Out:
#      platform                         name  total_sales
# 0         3DS               Beyblade Burst         0.03
# 1         3DS            Fire Emblem Fates         1.67
# 2         3DS         Frozen: Olaf's Quest         0.59
# 3         3DS   Haikyu!! Cross Team Match!         0.04
# 4         3DS     12-Sai. Honto no Kimochi         0.07
# ...       ...                          ...          ...
# 2889     XOne                       XCOM 2         0.04
# 2890     XOne                       ZombiU         0.01
# 2891     XOne          Zombie Army Trilogy         0.11
# 2892     XOne            Zoo Tycoon (2013)         0.36
# 2893     XOne   Zumba Fitness: World Party         0.24
#
# [2894 rows x 3 columns]

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x='platform',y='total_sales', data=global_sales, showfliers=False)
# Out:
# <AxesSubplot:xlabel='platform', ylabel='total_sales'>

# %% [markdown]
# After creating a boxplot I can see that we have various or platform with low and very high total sales.
# The best performing platform is the X360 and after it we have the PS4 going head to head with Wii and XOne.
# For the average sales, we can notice that for the over performing platform(PS3, PS4, Wii, WiiU, X360 and XOne) the mean is almost the same(except the X360 that is still better) and for the other 5 platform, they are under performing and their average sales are also low.
# We can also see that we have alot of outliers for the leading platforms, means that there are games and generated alot of revenue, much more from the mean that pushed the revenue much further. Some big games that that carried the rest of the statistic up the revenue table.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
# Very good.
#
# </div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 </b>
#
#
# What can you say about the outliers here?</div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
#
# Yes, you're right. Outliers are just some very popular games. I would even say bestsellers. And this is a very demonstrative thing. Look at the 3DS. Small box and lots of outliers. This suggests that a large part of the sales volume comes from these outliers. At the same time, the XOne has a different situation: a large box, a long whisker and few outliers. This indicates that a wide variety of games are bought on XOne, and, moreover, in considerable quantities.
#
# </div>

# %% [markdown]
# ### Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.

# %%
pc_review_sales = relevant_data.query('platform == "PC"')

# %%
pc_review_sales
# Out:
#                                         name platform  year_of_release  \
# 192                               Diablo III       PC             2012
# 458                               The Sims 4       PC             2014
# 688                             Guild Wars 2       PC             2012
# 959     World of Warcraft: Mists of Pandaria       PC             2012
# 1095        StarCraft II: Heart of the Swarm       PC             2013
# ...                                      ...      ...              ...
# 16584        Transformers: Fall of Cybertron       PC             2012
# 16617  Codename: Panzers Complete Collection       PC             2016
# 16631        The Amazing Spider-Man 2 (2014)       PC             2014
# 16678                         End of Nations       PC             2012
# 16692      Metal Gear Solid V: Ground Zeroes       PC             2014
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 192    Role-Playing      2.44      2.16       0.0         0.54          88.0
# 458      Simulation      1.00      1.82       0.0         0.23          70.0
# 688          Action      0.96      1.07       0.0         0.27          90.0
# 959    Role-Playing      0.84      0.76       0.0         0.22          82.0
# 1095       Strategy      0.83      0.66       0.0         0.18          86.0
# ...             ...       ...       ...       ...          ...           ...
# 16584        Action      0.01      0.00       0.0         0.00          78.0
# 16617      Strategy      0.00      0.01       0.0         0.00           NaN
# 16631        Action      0.00      0.01       0.0         0.00           NaN
# 16678      Strategy      0.01      0.00       0.0         0.00           NaN
# 16692        Action      0.00      0.01       0.0         0.00          80.0
#
#        user_score rating  total_sales
# 192           4.0      M         5.14
# 458           3.9      T         3.05
# 688           7.9      T         2.30
# 959           4.8      T         1.82
# 1095          7.9      T         1.67
# ...           ...    ...          ...
# 16584         7.9      T         0.01
# 16617         NaN    NaN         0.01
# 16631         NaN    NaN         0.01
# 16678         NaN      T         0.01
# 16692         7.6      M         0.01
#
# [250 rows x 12 columns]

# %%
def dif_platform(name_platform):
    platform = relevant_data[relevant_data['platform']==name_platform]
    fig,ax = plt.subplots(1,2,figsize=(15,10))
    sns.scatterplot(x='user_score', y='total_sales',data = platform, ax=ax[0], facecolor='red')
    sns.scatterplot(x='critic_score', y='total_sales',data = platform, ax=ax[1], facecolor='blue')
    fig.suptitle(name_platform, fontsize=15)
    ax[0].set(xlabel='user_score')
    ax[0].set(ylabel='total_sales')
    ax[1].set(xlabel='critic_score')
    ax[1].set(ylabel='total_sales')
    plt.show()
    
    user_corr = platform['user_score'].corr(platform['total_sales'])
    critic_corr = platform['critic_score'].corr(platform['total_sales'])
    
    if critic_corr >= 0.7:
        print('Correlation between critic score and platform', name_platform, ': Strong', critic_corr)
    elif 0.7 >= critic_corr >= 0.3:
        print('Correlation between critic score and platform', name_platform, ': Average', critic_corr)
    elif 0.3 >= critic_corr > 0:
        print('Correlation between critic score and platform', name_platform, ': Weeak', critic_corr)
        
    if user_corr >= 0.7:
        print('Correlation between user score and platform', name_platform, ': Strong', user_corr)
    elif 0.7 >= user_corr >= 0.3:
        print('Correlation between user score and platform', name_platform, ': Average', user_corr)
    elif 0.3 >= user_corr >= 0:
        print('Correlation between user score and platform', name_platform, ': Weak', user_corr)

        print('\n')

# %%
platform_array = relevant_data['platform'].unique()

# %%
platform_array
# Out:
# array(['PS3', 'X360', 'PS4', '3DS', 'DS', 'XOne', 'WiiU', 'Wii', 'PC',
#        'PSV', 'PSP'], dtype=object)

# %%
platform_list = ['PS4', 'XOne', 'PC', 'WiiU', '3DS']

# %%
for platform in platform_list:
    dif_platform(platform)
# Out:
# Correlation between critic score and platform PS4 : Average 0.40656790206178095
# Correlation between critic score and platform XOne : Average 0.4169983280084017
# Correlation between critic score and platform PC : Weeak 0.23724324311567915
# Correlation between critic score and platform WiiU : Average 0.34837976012017485
# Correlation between user score and platform WiiU : Average 0.4002190202148617
# Correlation between critic score and platform 3DS : Average 0.323378043752059
# Correlation between user score and platform 3DS : Weak 0.20373479097542724

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
# This piece of code didn't work. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# Didn't work again. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# Now it works, good job here.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# What about this one?
#
#
# ![image.png](attachment:image.png)
# </div>

# %%
mean_sales = relevant_data['total_sales'].mean()

# %%
mean_sales
# Out:
# 0.5001658031088084

# %%
games_genre = relevant_data.groupby(['genre'])['total_sales'].mean().reset_index()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
# Yes, it's a right decision to take mean values.
#
# </div>

# %%
games_genre
# Out:
#            genre  total_sales
# 0         Action     0.427829
# 1      Adventure     0.097426
# 2       Fighting     0.408165
# 3           Misc     0.442917
# 4       Platform     0.717647
# 5         Puzzle     0.174643
# 6         Racing     0.461983
# 7   Role-Playing     0.519059
# 8        Shooter     1.291525
# 9     Simulation     0.434268
# 10        Sports     0.673197
# 11      Strategy     0.187887

# %%
sort_genre = games_genre.groupby(['genre'])['total_sales'].mean().reset_index().sort_values(by='total_sales')['genre']

# %%
games_genre.sort_values(by='total_sales', ascending=False)
# Out:
#            genre  total_sales
# 8        Shooter     1.291525
# 4       Platform     0.717647
# 10        Sports     0.673197
# 7   Role-Playing     0.519059
# 6         Racing     0.461983
# 3           Misc     0.442917
# 9     Simulation     0.434268
# 0         Action     0.427829
# 2       Fighting     0.408165
# 11      Strategy     0.187887
# 5         Puzzle     0.174643
# 1      Adventure     0.097426

# %% [markdown]
# We can notice that the most popular genres are Shooter(by far with a 1.3M seles), Platform(with 0.71M sales), Sports(with 0.67M sales), ROle-Playing(with 0.51M sales) and Racing(with 0.46M sales).
# The lowest is Adventure(with only 0.09M).

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
# Try to sort data :) Then reconsider the conclusion. </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
# Sort sale values - not genre names. Action is not the best one according to the table above. Action's value is 0.4 and Adventure's is only 0.09. Frankly, I don't understand how Adventure can be promising, while Shooter has 1.29 which is definitely larger than the mean values of Action, Adventure, Fighting, Misc and Platform.
#
#
# Please, reconsider the conclusion.</div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 7 </h2>
#
# Here they are :) Now its' correct 👌 Shooter games are more successful on average.
#
# </div>

# %% [markdown]
# # Create a user profile for each region

# %%
relevant_data.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3             2013        Action
# 23          Grand Theft Auto V     X360             2013        Action
# 31   Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33         Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34  Call of Duty: Black Ops II      PS3             2012       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38           NaN         NaN
# 33      5.28      4.19      4.35         0.78           NaN         NaN
# 34      4.99      5.73      0.65         2.42          83.0         5.3
#
#    rating  total_sales
# 16      M        21.05
# 23      M        16.27
# 31    NaN        14.63
# 33    NaN        14.60
# 34      M        13.79

# %%
relevant_data['rating'] = relevant_data['rating'].replace(np.NaN, 'no rating')
# Out:
# /tmp/ipykernel_72/1759570186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   relevant_data['rating'] = relevant_data['rating'].replace(np.NaN, 'no rating')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# There's nothing bad in this message, it's just a warning. By the way, warnings can be ignored:
# </div>
#
# ```python
#
# import warnings
#
# warnings.filterwarnings('ignore')
# ```

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# Relevant data is not used. It should be suspicious that we don't see PS4 and Xone.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
# Still not used.
#
# </div>

# %%
na_sales = relevant_data.groupby(['platform'])['na_sales'].sum().reset_index().sort_values(by='na_sales',ascending=False)

# %%
na_sales.head()
# Out:
#    platform  na_sales
# 9      X360    140.05
# 4       PS4    108.74
# 3       PS3    103.38
# 10     XOne     93.12
# 0       3DS     56.15

# %%
eu_sales = relevant_data.groupby(['platform'])['eu_sales'].sum().reset_index().sort_values(by='eu_sales',ascending=False)

# %%
eu_sales.head()
# Out:
#    platform  eu_sales
# 4       PS4    141.09
# 3       PS3    106.86
# 9      X360     74.52
# 10     XOne     51.59
# 0       3DS     42.85

# %%
jp_sales = relevant_data.groupby(['platform'])['jp_sales'].sum().reset_index().sort_values(by='jp_sales',ascending=False)

# %%
jp_sales.head()
# Out:
#   platform  jp_sales
# 0      3DS     87.84
# 3      PS3     35.29
# 6      PSV     21.11
# 4      PS4     15.96
# 8     WiiU     13.01

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# Seem like in Japan people more likely prefer portable platforms and japanese market. We definitely should not recommend them XBox :)
#
# </div>

# %%
merge_sales = na_sales.merge(eu_sales, how='outer', on=['platform'])

# %%
merge_sales.head()
# Out:
#   platform  na_sales  eu_sales
# 0     X360    140.05     74.52
# 1      PS4    108.74    141.09
# 2      PS3    103.38    106.86
# 3     XOne     93.12     51.59
# 4      3DS     56.15     42.85

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2</b>
#
#
# This one didnt' too. Please, make sure everything works fine.  </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3</b>
#
# I still cannot run the whole project.   </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4 </b>
#
# My comments are not relevant anymore, everything works fine.
# </div>

# %%
merge_all_sales = merge_sales.merge(jp_sales, how='outer', on=['platform'])

# %%
merge_all_sales.head()
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 0     X360    140.05     74.52      1.57
# 1      PS4    108.74    141.09     15.96
# 2      PS3    103.38    106.86     35.29
# 3     XOne     93.12     51.59      0.34
# 4      3DS     56.15     42.85     87.84

# %% [markdown]
# #### I have created three values,one for each continent and grouped them by sales.
# After wards a merged all of them to see which is the top platform in each continent and by which difference from the other.
# We can notice that the Xbox 360 is the leader in sales for north america but for europe the first place goes for PS4(when PS3 comes after on the 2nd place with 107M). As for japan, the best seller for them was the 3DS.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# Don't forget to adjust the conclusions as well :) This is the old one :)
# </div>

# %%
na_rating = relevant_data.groupby(['rating'])['na_sales'].sum().reset_index().sort_values(by='na_sales', ascending=False)

# %%
na_rating.head()
# Out:
#       rating  na_sales
# 2          M    231.57
# 0          E    114.49
# 4  no rating    103.59
# 1       E10+     75.96
# 3          T     66.31

# %%
eu_rating = relevant_data.groupby(['rating'])['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False)

# %%
eu_rating
# Out:
#       rating  eu_sales
# 2          M    193.96
# 0          E    113.05
# 4  no rating     91.50
# 1       E10+     55.56
# 3          T     53.01

# %%
jp_rating = relevant_data.groupby(['rating'])['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False)

# %%
jp_rating.head()
# Out:
#       rating  eu_sales
# 2          M    193.96
# 0          E    113.05
# 4  no rating     91.50
# 1       E10+     55.56
# 3          T     53.01

# %%
merge_rating = na_rating.merge(eu_rating, how='outer', on=['rating'])

# %%
merge_rating.head()
# Out:
#       rating  na_sales  eu_sales
# 0          M    231.57    193.96
# 1          E    114.49    113.05
# 2  no rating    103.59     91.50
# 3       E10+     75.96     55.56
# 4          T     66.31     53.01

# %%
merge_all_rating = merge_rating.merge(jp_rating, how='outer', on=['rating'])

# %%
merge_all_rating
# Out:
#       rating  na_sales  eu_sales_x  eu_sales_y
# 0          M    231.57      193.96      193.96
# 1          E    114.49      113.05      113.05
# 2  no rating    103.59       91.50       91.50
# 3       E10+     75.96       55.56       55.56
# 4          T     66.31       53.01       53.01

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# The missing age rating should also be considered here, being preliminarily replaced  with a marker value. For example, with *No rating*. With such replacement games without rating will also be displayed on chart and table. If they occured in a specific region, we will see it in the distributions.
#
#
# This task is a great example of how even missing values can carry important information.
# </div>

# %% [markdown]
# I have created three values,one for each continent and grouped them by rating.
# After wards a merged all of them to see which is the top platform in each continent and by which difference from the other.
# We can notice that the E rating is the most common for all three datas.
# But i think the problem is because we didnt have the missing values for this column so its hard to say.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
#
# Japan shows the difference again. Most likely, the point is,  the ESRB works only in  NA, whereas  there is a similar organization in Japan: CERO. I think that, on the one hand, they (ESRB) do not assign ratings, since they already have markings on games. So it's quite possible that some of these games are Japanese games. On the other hand, since they sell games on their marketplace, assigning a rating can be mandatory. So the point may be that our table is a merging of two tables: West sales and  East sales. Anyway, it is a very illustrative example. And this difference in the markets (East and West) prompts that the Nan-s are not accidental.
#
#
# </div>

# %% [markdown]
# ** Interesting, I didnt know that. Thank you. **

# %%
na_genre = relevant_data.groupby(['genre'])['na_sales'].sum().reset_index().sort_values(by='na_sales', ascending=False)

# %%
na_genre.head()
# Out:
#            genre  na_sales
# 0         Action    178.02
# 8        Shooter    144.81
# 10        Sports     81.53
# 7   Role-Playing     64.11
# 3           Misc     38.19

# %%
eu_genre = relevant_data.groupby(['genre'])['eu_sales'].sum().reset_index().sort_values(by='eu_sales', ascending=False)

# %%
eu_genre.head()
# Out:
#            genre  eu_sales
# 0         Action    159.53
# 8        Shooter    113.49
# 10        Sports     69.09
# 7   Role-Playing     48.58
# 6         Racing     27.29

# %%
jp_genre = relevant_data.groupby(['genre'])['jp_sales'].sum().reset_index().sort_values(by='jp_sales', ascending=False)

# %%
jp_genre.head()
# Out:
#           genre  jp_sales
# 7  Role-Playing     65.54
# 0        Action     52.80
# 3          Misc     12.86
# 9    Simulation     10.41
# 2      Fighting      9.44

# %%
merge_genre = na_genre.merge(eu_genre, how='outer', on=['genre'])

# %%
merge_genre.head()
# Out:
#           genre  na_sales  eu_sales
# 0        Action    178.02    159.53
# 1       Shooter    144.81    113.49
# 2        Sports     81.53     69.09
# 3  Role-Playing     64.11     48.58
# 4          Misc     38.19     26.32

# %%
merge_all_genre = merge_genre.merge(jp_genre, how='outer', on=['genre'])

# %%
merge_all_genre.head()
# Out:
#           genre  na_sales  eu_sales  jp_sales
# 0        Action    178.02    159.53     52.80
# 1       Shooter    144.81    113.49      9.23
# 2        Sports     81.53     69.09      8.03
# 3  Role-Playing     64.11     48.58     65.54
# 4          Misc     38.19     26.32     12.86

# %% [markdown]
# I have created three values,one for each continent and grouped them by sales.
# After wards a merged all of them to see which is the top platform in each continent and by which difference from the other.
# We can notice that the action genre is the leader in sales for all 3 of the datas when is north america has the largest sales in this genre. After it comes the Sports genre, aslo for 3 of the datas we checked.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# The distributions may change after the period slice is rectified, so don't forget to reconsider the conclusions.
# </div>

# %% [markdown]
# # Test the following hypotheses:

# %% [markdown]
# ### Average user ratings of the Xbox One and PC platforms are the same.

# %%
xbox1 = relevant_data[(relevant_data['platform']=='XOne')&(relevant_data['user_score'].notna())]['user_score']

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# - Relevant data is not used.
#
#
# - XB is not XOne.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
# Ok, we have XOne here. Now let's adjust the dataframe. As you remember, we have to use only relevant, fresh data.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
#
# Yes, now it's good :)
#
# </div>

# %%
xbox1
# Out:
# 165      7.9
# 179      5.4
# 242      6.4
# 270      6.2
# 373      4.1
#         ...
# 16544    6.8
# 16597    6.0
# 16630    8.2
# 16643    6.6
# 16660    6.7
# Name: user_score, Length: 182, dtype: float64

# %%
pc = relevant_data[(relevant_data['platform']=='PC')&(relevant_data['user_score'].notna())]['user_score']

# %%
pc
# Out:
# 192      4.0
# 458      3.9
# 688      7.9
# 959      4.8
# 1095     7.9
#         ...
# 16463    6.8
# 16509    7.9
# 16518    1.4
# 16584    7.9
# 16692    7.6
# Name: user_score, Length: 206, dtype: float64

# %%
from scipy.stats import levene
stat, p = levene(xbox1, pc)
p<0.05
# Out:
# True

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment 4</b>
#
#
# [PEP8](https://peps.python.org/pep-0008/) states that one should always put import at the top of the file. It's a good practice, since everyone who is going to read the project, can immediately figure out what modules need to be installed.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# It's safe to always assume that the variances differ. They are going to be the same only when the average values are the same, which is hard to achieve in real life. Here's a [link to a paper about the unnecessity of preliminary tests of equality of variances](https://pubmed.ncbi.nlm.nih.gov/15171807/)
# </div>

# %%
from scipy import stats
stats.ttest_ind(xbox1, pc, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.5998585993590416, pvalue=0.5489537965134912)

# %%
stats.ttest_ind(xbox1, pc).pvalue<0.05
# Out:
# False

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
#
# So we do not reject this hypothesis.
#
# </div>

# %% [markdown]
# ### Average user ratings for the Action and Sports genres are different.

# %%
action = relevant_data[(relevant_data['genre']=='Action')&(relevant_data['user_score'].notna())]['user_score']

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# Old dataframe is used. Be careful :)
# </div>

# %%
action
# Out:
# 16       8.2
# 23       8.1
# 42       8.3
# 81       6.6
# 127      6.9
#         ...
# 16597    6.0
# 16652    8.5
# 16654    5.1
# 16660    6.7
# 16692    7.6
# Name: user_score, Length: 524, dtype: float64

# %%
sports = relevant_data[(relevant_data['genre']=='Sports')&(relevant_data['user_score'].notna())]['user_score']

# %%
sports
# Out:
# 77       4.3
# 94       5.0
# 126      4.3
# 143      5.7
# 264      4.5
#         ...
# 16146    6.9
# 16230    5.5
# 16450    4.5
# 16518    1.4
# 16643    6.6
# Name: user_score, Length: 195, dtype: float64

# %%
stat, p = levene(action, sports)
p<0.05
# Out:
# True

# %%
stats.ttest_ind(action, sports, equal_var=False)
# Out:
# Ttest_indResult(statistic=9.90217634887622, pvalue=4.305337670692197e-20)

# %%
stats.ttest_ind(action, sports).pvalue<0.05
# Out:
# True

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 7 </h2>
#
# Yes, now we reject it under a chosen $\alpha$.
# </div>

# %% [markdown]
# My null hypothesis was that the average user ratings of Action and Sports genre will be the same.
# The alternative hypotheses was that the average wone be the same.
#
# After testing my hypotheses we can notice that the pvalue is greater then 0.05 alpa as we mentioned before(less then 5%) and the hypotheses was right.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# Please, add a conclusion for this part of analysis.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
#
#
# Thank you.
#
# </div>

# %% [markdown]
# # Coclusion
# I have started my project from importing the data and checking it.
# I noticed that i have alot of missing values in the last 3 columns(and also 2 column with 2 missing vlaues and 1 column with around 250 values missing).
# Firstly I strated chenging the data type for some of the columns for easier working.
# After that, I grouped the missing values for year of release by the platform.
# Then, I attended to the 2 missing values in the name and genre column.
# I had problem filling the missing values in the critis/user score and the rating because we couldnt just erase them because they were around 50% of the data and also we couldnt fill in them without knowing what could be the value so i grouped each column by the name of the game to find at least some of the values.
# Only after that I could start analysing the data.
# 1. I have created a lolipop graph to show the released games, year by year to see when we had the highest peak, that was around the 2008-2009 and then started falling.
# 2. When I saw that most of the games are underperforming but the games that are over performing are extremly over bought, I decided to created a new, more relevant data, that began from the 2000 so my data would be more relevant to check with platform are newer and which are older.
# 3. After ploting a line graph, I have noticed that till the 2010, most of the platform managed to stay for long time but then, each platform began to fade away quieker (with a mean of 6.5 years for all of the data).
# 4. I noticed that the data that is more relevant to me is the data after the 2012 so I have created a new data frame that begand from that year.
# 5. Then, I checked which of the platform are the best performers and found ou that the Xbox360,Xboxone, PS3 and the PS4 are the best performers year by year and I have created a heat map to see it more visually.
# 6. Then, I created a boxplot to check how all games are performing in sales by each platform and found out that the main platforms that are doing well are: PS3, PS4, Wii, WiiU, Xbox 360 and Xbox One.
# 7. Afterwards, I created a function with a scatter plot to determine the users and the proffessionals affect the sales of the games but the problem was that I had alot of missing values for both of them so i could generate only half of all the information.
# I finished with the analysation and started grouping the data by 2 continents and japan to check how sales of platforms, regions and genres by user scores differs from each other.
# Then, I tested 2 hypothesis, one for the Xbox and PC platfor and one for the Action and Sports genre by rating.
#
# After testing our hypothesis and checking the data, we found out that Xbox One and PS4 are the main platform to buy games for them, especially the Action, Shooter and the

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
#
# The conclusion is written very well.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 4</b>
#
# It will be great if you modify the list of promising platforms and add more information about regions: 2-3 platforms, 2-3 genres and age ratings.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 5</b>
#
# List of promising should be modified. </div>

# %% [markdown]
# ** What does it mean "List of promising"? **

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 6</b>
#
#
# Just a list of platforms that are most promising, those platforms that we should pay attention to in the next year. We defined them right before the boxplot part. These are: PS4 and XOne.
#
#
# In the conclusion above you're writing:
#
#     Then, I checked which of the platform are the best performers and found ou that the Xbox360,Xboxone, PS3 and the PS4 are the best performers year by year and I have created a heat map to see it more visually.
#
#
# which is not exactly true. We should rectify it a little bit, since X360 and PS3 are dying.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 7 </h2>
#
# To sum up, the platforms we should pay attention to are: PS4, XOne, 3DS.
#
#
# For NA and EU we should consider new generations of XBox and PS, while in Japan people prefer their own production: new generations of DS and PS (3ds and ps4). We should also admit that while on the West people prefer Action and Shooter, Japanese people prefer RPG and Action.
# </div>
